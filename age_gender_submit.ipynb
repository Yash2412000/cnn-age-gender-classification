# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and predict their gender based on face images. Please read carefully all the instructions before you start to write your code.
#
# **Your Tasks**
#
# You are supposed to train two CNN models.
# - Model A: Train a CNN model from scratch, following a few restrictions. Save this model as `age_gender_A.keras`
# - Model B: Fine-tune a pre-trained model to perform the same task. Save this model as `age_gender_B.keras`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During the assessment phase, your code will be tested on unseen test data.
#
# **Performance Metric**
#
# The evaluation of your models on the test set will be based on the following metrics:
# - age estimation: - Mean Absolute Error (MAE)
# - gender prediction: accuracy
#
# **GPU Time Management**
#
# Please use the available GPU time wisely, as there are some limitations on free GPU usage. It is said the users can use up to 12 hours in row in Google Colab. But many people found they reached its limit far less than 12 hours. To minimize the risk of reaching the limit, consider the following suggestions:
# 1. Ensure you have a stable internet connection.
# 2. Carefully validate your hyperparameters before starting the training process.
# 3. Based on past experience, each model should be trained in less than 2 hours. If the training time is significantly longer, you may need to adjust your model architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook. Also don't forget to **enable GPU** before your training.

# %%
#
# Add your code here
#
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Visualize a few photos
# It's always beneficial to thoroughly understand your data before beginning the training process. To get a first-hand impression of the dataset, please display a minimum of 20 images from the `train_val/` folder, along with their corresponding age and gender labels. This will help you gain initial insights into the dataset.

# %%
#
# Add your code here
#
import pandas as pd
import random
from os import listdir
import matplotlib.pyplot as plt
import cv2
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from PIL import Image

photos = "/content/drive/MyDrive/train_val"
rand_images = os.listdir(photos)
twenty= random.sample(rand_images, 20)
random.shuffle(rand_images)
images_20 = twenty[:20]

plt.figure(figsize=(15, 10))
for i, img_name in enumerate(twenty):
    img_path = os.path.join(photos, img_name)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    try:
        parts = img_name.split("_")
        age = parts[0]
        gender = parts[1]
        gender_label = 'Female' if gender == '1' else 'Male'
        label = f"Age: {age}, Gender: {gender_label}"
    except:
        label = "Label not found"
    plt.subplot(4, 5, i + 1)
    plt.imshow(img)
    plt.title(label)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 1: Data Pre-Processing
# In this step, you will perform necessary pre-processing tasks before feeding the data into a CNN. The pre-processing includes:
#
# 1. Splitting the data into training and validation sets.
# 2. Loading image data, gender labels and age values, and rescaling pixel values (originally integers between 0 and 255) to the range [0, 1].
# 3. Data augmentation
#
# The first two pre-processing steps have already been completed for you. Your task in this step is limited to:
#
# 3. Data augmentation
#
# Please note:
#
# - Do not modify any part of the provided code except the section marked with ########.
# - Do not rescale the age values to the range [0,1], as the original values are used during the testing stage. Rescaling them would significantly impact testing performance.

# %%
import numpy as np
import tensorflow as tf
from keras import layers

folder_train_val = "/content/drive/MyDrive/train_val"
all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

# Shuffle the dataset to ensure random distribution
random.seed(0)  # Ensure reproducibility
random.shuffle(all_image_files)

# Calculate the number of images for each set
n_train_val = len(all_image_files)
train_end = int(n_train_val * 0.8)

# Split the dataset
train_image_files = all_image_files[:train_end]
val_image_files = all_image_files[train_end:]
print(f"Number of images for training: {len(train_image_files)}")
print(f"Number of images for validation: {len(val_image_files)}")

def load_imgs_lables(dataset_path,filenames):
  print('load all image data, age and gender labels...')
  images = []
  age_labels = []
  gender_labels = []
  for current_file_name in filenames:
    img = cv2.imread(os.path.join(dataset_path, current_file_name))
    # Add a check for None in case image loading fails
    if img is None:
        print(f"Warning: Could not load image {current_file_name}. Skipping.")
        continue

    # Convert from BGR to RGB format (OpenCV reads BGR, Matplotlib expects RGB)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255.0  # Normalize pixel values
    labels = current_file_name.split('_')
    try:
        age_label = int(labels[0])
        gender_label = int(labels[1])
    except (ValueError, IndexError):
        print(f"Warning: Could not parse age/gender from {current_file_name}. Skipping.")
        continue
    age_labels.append(age_label)
    gender_labels.append(gender_label)
    images.append(img)

  # Convert to NumPy arrays
  images = np.array(images)
  age_labels = np.array(age_labels)
  gender_labels = np.array(gender_labels)
  return images, age_labels, gender_labels

# load data from the training set
train_images, train_age, train_gender = load_imgs_lables(folder_train_val,train_image_files)

# load data from the validation set
val_images, val_age, val_gender = load_imgs_lables(folder_train_val,val_image_files)

print("train_images:", train_images.shape)
print("train_age:", len(train_age))
print("train_gender:", len(train_gender))
print("val_images:", val_images.shape)
print("val_age:", len(val_age))
print("val_gender:", len(val_gender))

#
######### Add your code for data augmentation here #########
#

# Data augmentation layers
data_augmentation_layers = [
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.05),
]

def data_augmentation(image, labels):
    for layer in data_augmentation_layers:
        image = layer(image)
    return image, labels

# Create Tf datasets for training and validation
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, {'age_output': train_age, 'gender_output': train_gender}))
val_dataset = tf.data.Dataset.from_tensor_slices((val_images, {'age_output': val_age, 'gender_output': val_gender}))

# No augmentation for validation dataset
aug_val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

# Apply data augmentation to the training dataset, shuffle it, batch it, and prefetch
aug_train_dataset = train_dataset.map(data_augmentation, num_parallel_calls=tf.data.AUTOTUNE)
aug_train_dataset = aug_train_dataset.shuffle(len(train_images)).batch(32).prefetch(tf.data.AUTOTUNE)

# Visualize augmented images
plt.figure(figsize=(20, 10))
for images_batch, labels_batch in aug_train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images_batch[i])
        gender = "Female" if labels_batch['gender_output'][i] == 1 else "Male"
        plt.title(f"Age: {labels_batch['age_output'][i].numpy()}, Gender: {gender}")
plt.tight_layout()
plt.show()


print("aug_train_dataset element spec (image, labels dict):")
print(aug_train_dataset.element_spec)
print("aug_train_dataset number of batches:", tf.data.experimental.cardinality(aug_train_dataset).numpy())
print("aug_val_dataset element spec (image, labels dict):")
print(aug_val_dataset.element_spec)
print("aug_val_dataset number of batches:", tf.data.experimental.cardinality(aug_val_dataset).numpy())
# Out:
# Number of images for training: 4000
# Number of images for validation: 1000
# load all image data, age and gender labels...
# load all image data, age and gender labels...
# train_images: (4000, 128, 128, 3)
# train_age: 4000
# train_gender: 4000
# val_images: (1000, 128, 128, 3)
# val_age: 1000
# val_gender: 1000
# aug_train_dataset element spec (image, labels dict):
# (TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), {'age_output': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'gender_output': TensorSpec(shape=(None,), dtype=tf.int64, name=None)})
# aug_train_dataset number of batches: 125
# aug_val_dataset element spec (image, labels dict):
# (TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float64, name=None), {'age_output': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'gender_output': TensorSpec(shape=(None,), dtype=tf.int64, name=None)})
# aug_val_dataset number of batches: 32

# %% [markdown]
# ## STEP2A: Build your own CNN network
# In this step, you will define your own CNN model for identifying gender and predicting age. Although there are two tasks, you only need to build one CNN model with two outputs. You may refer to online resources for solutions.
#
# Here are the key requirements and restrictions for your network:
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2. Although it is technically correct to treat gender classification as a multi-class problem with 2 classes, i.e., 2 units in the last layer, the test code only supports a 1-unit last-layer configuration for the gender branch.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	Incorporate techniques to prevent overfitting as appropriate.
#
# At the end of your implementation, use `modelA.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsoluteError, BinaryCrossentropy
from tensorflow.keras.utils import plot_model

# Cnn Architecture
input_shape = (128, 128, 3)
inputs = layers.Input(shape=input_shape)

x = inputs

# 4 conv blocks with increasing filters
for filters in [32, 64, 128, 256]:
    x = layers.Conv2D(filters, 3, padding="same",activation="relu",kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(filters, 3, padding="same",activation="relu",kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.15)(x)

# global feature vector
x = layers.GlobalAveragePooling2D()(x)

# Shared dense representation
shared_layers = layers.Dense(512, activation="relu",kernel_initializer="he_normal")(x)
shared_layers = layers.Dropout(0.4)(shared_layers)

# Age Prediction
age_branch = layers.Dense(256, activation="relu",kernel_initializer="he_normal")(shared_layers)
age_branch = layers.Dropout(0.3)(age_branch)
age_output = layers.Dense(1, name="age_output")(age_branch)

# Gender classification
gender_branch = layers.Dense(128, activation="relu",kernel_initializer="he_normal")(shared_layers)
gender_branch = layers.Dropout(0.3)(gender_branch)
gender_output = layers.Dense(1, activation="sigmoid",name="gender_output")(gender_branch)

modelA = Model(inputs, [age_output, gender_output])

# Compile
modelA.compile(optimizer=Adam(learning_rate=1e-4),
    loss={"age_output": MeanAbsoluteError(),"gender_output": BinaryCrossentropy()},
    loss_weights={"age_output": 0.7,"gender_output": 0.3},
    metrics={"age_output": MeanAbsoluteError(),"gender_output": "accuracy"}
)

modelA.summary()
plot_model(modelA, to_file="modelA_architecture.png",show_shapes=True, dpi=100)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      9,248 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64, 64,    │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 8, 8, 256) │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dropout_3[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    131,584 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     65,664 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │        257 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 1)         │        129 │ dropout_6[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,505,058 (5.74 MB)
#  Trainable params: 1,503,138 (5.73 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.keras")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()`** to save the entire model (including a model's architecture, weights, and training configuration) as a `.keras` zip archive. Don't save it with `save_weights()`.

# %%
folder_models = '/content/drive/MyDrive/models/'

model_hist = modelA.fit(
    aug_train_dataset,
    validation_data=aug_val_dataset,
    epochs=60
)
modelA.save(folder_models+'age_gender_A.keras')
# Out:
# Epoch 1/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 36s 88ms/step - age_output_loss: 23.8854 - age_output_mean_absolute_error: 23.8854 - gender_output_accuracy: 0.5096 - gender_output_loss: 0.9744 - loss: 17.0121 - val_age_output_loss: 23.1446 - val_age_output_mean_absolute_error: 23.1446 - val_gender_output_accuracy: 0.5420 - val_gender_output_loss: 0.6914 - val_loss: 16.3362
# Epoch 2/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - age_output_loss: 13.9960 - age_output_mean_absolute_error: 13.9960 - gender_output_accuracy: 0.5334 - gender_output_loss: 0.8483 - loss: 10.0517 - val_age_output_loss: 23.0528 - val_age_output_mean_absolute_error: 23.0528 - val_gender_output_accuracy: 0.5090 - val_gender_output_loss: 0.7087 - val_loss: 16.2735
# Epoch 3/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - age_output_loss: 13.3099 - age_output_mean_absolute_error: 13.3099 - gender_output_accuracy: 0.5637 - gender_output_loss: 0.7742 - loss: 9.5492 - val_age_output_loss: 17.0216 - val_age_output_mean_absolute_error: 17.0216 - val_gender_output_accuracy: 0.5650 - val_gender_output_loss: 0.6791 - val_loss: 12.0783
# Epoch 4/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - age_output_loss: 12.5196 - age_output_mean_absolute_error: 12.5196 - gender_output_accuracy: 0.5950 - gender_output_loss: 0.7074 - loss: 8.9759 - val_age_output_loss: 11.6529 - val_age_output_mean_absolute_error: 11.6529 - val_gender_output_accuracy: 0.6670 - val_gender_output_loss: 0.6454 - val_loss: 8.3049
# Epoch 5/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - age_output_loss: 12.1868 - age_output_mean_absolute_error: 12.1868 - gender_output_accuracy: 0.5867 - gender_output_loss: 0.7097 - loss: 8.7437 - val_age_output_loss: 11.2309 - val_age_output_mean_absolute_error: 11.2309 - val_gender_output_accuracy: 0.6690 - val_gender_output_loss: 0.6384 - val_loss: 7.9766
# Epoch 6/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - age_output_loss: 11.4635 - age_output_mean_absolute_error: 11.4635 - gender_output_accuracy: 0.6227 - gender_output_loss: 0.6664 - loss: 8.2244 - val_age_output_loss: 24.9490 - val_age_output_mean_absolute_error: 24.9490 - val_gender_output_accuracy: 0.5800 - val_gender_output_loss: 0.7521 - val_loss: 17.5411
# Epoch 7/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - age_output_loss: 11.2723 - age_output_mean_absolute_error: 11.2723 - gender_output_accuracy: 0.6049 - gender_output_loss: 0.6839 - loss: 8.0958 - val_age_output_loss: 11.7676 - val_age_output_mean_absolute_error: 11.7676 - val_gender_output_accuracy: 0.6380 - val_gender_output_loss: 0.6526 - val_loss: 8.3198
# Epoch 8/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - age_output_loss: 10.4644 - age_output_mean_absolute_error: 10.4644 - gender_output_accuracy: 0.6252 - gender_output_loss: 0.6547 - loss: 7.5215 - val_age_output_loss: 10.5836 - val_age_output_mean_absolute_error: 10.5836 - val_gender_output_accuracy: 0.6680 - val_gender_output_loss: 0.6211 - val_loss: 7.5449
# Epoch 9/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 10.5157 - age_output_mean_absolute_error: 10.5157 - gender_output_accuracy: 0.6351 - gender_output_loss: 0.6453 - loss: 7.5546 - val_age_output_loss: 9.8392 - val_age_output_mean_absolute_error: 9.8392 - val_gender_output_accuracy: 0.6670 - val_gender_output_loss: 0.6276 - val_loss: 6.9821
# Epoch 10/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 10.2989 - age_output_mean_absolute_error: 10.2989 - gender_output_accuracy: 0.6399 - gender_output_loss: 0.6435 - loss: 7.4023 - val_age_output_loss: 9.9784 - val_age_output_mean_absolute_error: 9.9784 - val_gender_output_accuracy: 0.6700 - val_gender_output_loss: 0.6186 - val_loss: 7.0810
# Epoch 11/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - age_output_loss: 9.8425 - age_output_mean_absolute_error: 9.8425 - gender_output_accuracy: 0.6443 - gender_output_loss: 0.6385 - loss: 7.0813 - val_age_output_loss: 9.3425 - val_age_output_mean_absolute_error: 9.3425 - val_gender_output_accuracy: 0.6730 - val_gender_output_loss: 0.6106 - val_loss: 6.6247
# Epoch 12/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - age_output_loss: 9.9010 - age_output_mean_absolute_error: 9.9010 - gender_output_accuracy: 0.6368 - gender_output_loss: 0.6382 - loss: 7.1222 - val_age_output_loss: 8.9982 - val_age_output_mean_absolute_error: 8.9982 - val_gender_output_accuracy: 0.6750 - val_gender_output_loss: 0.6061 - val_loss: 6.4267
# Epoch 13/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 9.4202 - age_output_mean_absolute_error: 9.4202 - gender_output_accuracy: 0.6440 - gender_output_loss: 0.6384 - loss: 6.7856 - val_age_output_loss: 9.9786 - val_age_output_mean_absolute_error: 9.9786 - val_gender_output_accuracy: 0.6360 - val_gender_output_loss: 0.6229 - val_loss: 7.1518
# Epoch 14/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 9.5356 - age_output_mean_absolute_error: 9.5356 - gender_output_accuracy: 0.6482 - gender_output_loss: 0.6338 - loss: 6.8651 - val_age_output_loss: 9.6329 - val_age_output_mean_absolute_error: 9.6329 - val_gender_output_accuracy: 0.6680 - val_gender_output_loss: 0.6059 - val_loss: 6.8659
# Epoch 15/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 9.2860 - age_output_mean_absolute_error: 9.2860 - gender_output_accuracy: 0.6546 - gender_output_loss: 0.6249 - loss: 6.6877 - val_age_output_loss: 9.6636 - val_age_output_mean_absolute_error: 9.6636 - val_gender_output_accuracy: 0.6760 - val_gender_output_loss: 0.6146 - val_loss: 6.8916
# Epoch 16/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 8.8025 - age_output_mean_absolute_error: 8.8025 - gender_output_accuracy: 0.6488 - gender_output_loss: 0.6380 - loss: 6.3531 - val_age_output_loss: 9.2639 - val_age_output_mean_absolute_error: 9.2639 - val_gender_output_accuracy: 0.6840 - val_gender_output_loss: 0.5994 - val_loss: 6.5770
# Epoch 17/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 8.7405 - age_output_mean_absolute_error: 8.7405 - gender_output_accuracy: 0.6564 - gender_output_loss: 0.6262 - loss: 6.3062 - val_age_output_loss: 8.4866 - val_age_output_mean_absolute_error: 8.4866 - val_gender_output_accuracy: 0.6710 - val_gender_output_loss: 0.6046 - val_loss: 6.0413
# Epoch 18/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 8.4567 - age_output_mean_absolute_error: 8.4567 - gender_output_accuracy: 0.6682 - gender_output_loss: 0.6116 - loss: 6.1031 - val_age_output_loss: 9.2155 - val_age_output_mean_absolute_error: 9.2155 - val_gender_output_accuracy: 0.6690 - val_gender_output_loss: 0.6016 - val_loss: 6.6473
# Epoch 19/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 8.5738 - age_output_mean_absolute_error: 8.5738 - gender_output_accuracy: 0.6580 - gender_output_loss: 0.6220 - loss: 6.1883 - val_age_output_loss: 9.5187 - val_age_output_mean_absolute_error: 9.5187 - val_gender_output_accuracy: 0.6800 - val_gender_output_loss: 0.6031 - val_loss: 6.8370
# Epoch 20/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 8.5956 - age_output_mean_absolute_error: 8.5956 - gender_output_accuracy: 0.6496 - gender_output_loss: 0.6231 - loss: 6.2039 - val_age_output_loss: 8.4578 - val_age_output_mean_absolute_error: 8.4578 - val_gender_output_accuracy: 0.6870 - val_gender_output_loss: 0.5899 - val_loss: 6.0512
# Epoch 21/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 8.2979 - age_output_mean_absolute_error: 8.2979 - gender_output_accuracy: 0.6675 - gender_output_loss: 0.6063 - loss: 5.9904 - val_age_output_loss: 9.1227 - val_age_output_mean_absolute_error: 9.1227 - val_gender_output_accuracy: 0.6930 - val_gender_output_loss: 0.5889 - val_loss: 6.4779
# Epoch 22/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 8.4435 - age_output_mean_absolute_error: 8.4435 - gender_output_accuracy: 0.6739 - gender_output_loss: 0.6149 - loss: 6.0950 - val_age_output_loss: 8.9054 - val_age_output_mean_absolute_error: 8.9054 - val_gender_output_accuracy: 0.6830 - val_gender_output_loss: 0.5849 - val_loss: 6.3647
# Epoch 23/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.9774 - age_output_mean_absolute_error: 7.9774 - gender_output_accuracy: 0.6905 - gender_output_loss: 0.5929 - loss: 5.7621 - val_age_output_loss: 9.1450 - val_age_output_mean_absolute_error: 9.1450 - val_gender_output_accuracy: 0.7060 - val_gender_output_loss: 0.5770 - val_loss: 6.5223
# Epoch 24/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.7564 - age_output_mean_absolute_error: 7.7564 - gender_output_accuracy: 0.6630 - gender_output_loss: 0.6105 - loss: 5.6126 - val_age_output_loss: 8.2506 - val_age_output_mean_absolute_error: 8.2506 - val_gender_output_accuracy: 0.7080 - val_gender_output_loss: 0.5684 - val_loss: 5.9301
# Epoch 25/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.8697 - age_output_mean_absolute_error: 7.8697 - gender_output_accuracy: 0.6805 - gender_output_loss: 0.5931 - loss: 5.6867 - val_age_output_loss: 8.4100 - val_age_output_mean_absolute_error: 8.4100 - val_gender_output_accuracy: 0.7030 - val_gender_output_loss: 0.5743 - val_loss: 6.0508
# Epoch 26/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.9935 - age_output_mean_absolute_error: 7.9935 - gender_output_accuracy: 0.6963 - gender_output_loss: 0.5861 - loss: 5.7713 - val_age_output_loss: 8.4677 - val_age_output_mean_absolute_error: 8.4677 - val_gender_output_accuracy: 0.7020 - val_gender_output_loss: 0.5596 - val_loss: 6.0804
# Epoch 27/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.9468 - age_output_mean_absolute_error: 7.9468 - gender_output_accuracy: 0.6887 - gender_output_loss: 0.5942 - loss: 5.7410 - val_age_output_loss: 9.7023 - val_age_output_mean_absolute_error: 9.7023 - val_gender_output_accuracy: 0.7140 - val_gender_output_loss: 0.5499 - val_loss: 6.9688
# Epoch 28/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.8725 - age_output_mean_absolute_error: 7.8725 - gender_output_accuracy: 0.6894 - gender_output_loss: 0.5773 - loss: 5.6840 - val_age_output_loss: 8.4024 - val_age_output_mean_absolute_error: 8.4024 - val_gender_output_accuracy: 0.7110 - val_gender_output_loss: 0.5610 - val_loss: 6.0561
# Epoch 29/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.6947 - age_output_mean_absolute_error: 7.6947 - gender_output_accuracy: 0.7152 - gender_output_loss: 0.5522 - loss: 5.5520 - val_age_output_loss: 8.6259 - val_age_output_mean_absolute_error: 8.6259 - val_gender_output_accuracy: 0.7390 - val_gender_output_loss: 0.5342 - val_loss: 6.1972
# Epoch 30/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - age_output_loss: 7.3625 - age_output_mean_absolute_error: 7.3625 - gender_output_accuracy: 0.7166 - gender_output_loss: 0.5658 - loss: 5.3235 - val_age_output_loss: 8.3569 - val_age_output_mean_absolute_error: 8.3569 - val_gender_output_accuracy: 0.7420 - val_gender_output_loss: 0.5273 - val_loss: 6.0278
# Epoch 31/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.5562 - age_output_mean_absolute_error: 7.5562 - gender_output_accuracy: 0.7202 - gender_output_loss: 0.5602 - loss: 5.4574 - val_age_output_loss: 8.3436 - val_age_output_mean_absolute_error: 8.3436 - val_gender_output_accuracy: 0.7400 - val_gender_output_loss: 0.5181 - val_loss: 6.0316
# Epoch 32/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.1852 - age_output_mean_absolute_error: 7.1852 - gender_output_accuracy: 0.7152 - gender_output_loss: 0.5615 - loss: 5.1981 - val_age_output_loss: 8.8143 - val_age_output_mean_absolute_error: 8.8143 - val_gender_output_accuracy: 0.7590 - val_gender_output_loss: 0.5127 - val_loss: 6.2961
# Epoch 33/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.4114 - age_output_mean_absolute_error: 7.4114 - gender_output_accuracy: 0.7245 - gender_output_loss: 0.5453 - loss: 5.3516 - val_age_output_loss: 8.0567 - val_age_output_mean_absolute_error: 8.0567 - val_gender_output_accuracy: 0.7580 - val_gender_output_loss: 0.4968 - val_loss: 5.7617
# Epoch 34/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.1320 - age_output_mean_absolute_error: 7.1320 - gender_output_accuracy: 0.7116 - gender_output_loss: 0.5558 - loss: 5.1591 - val_age_output_loss: 8.1342 - val_age_output_mean_absolute_error: 8.1342 - val_gender_output_accuracy: 0.7540 - val_gender_output_loss: 0.4993 - val_loss: 5.8705
# Epoch 35/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.9278 - age_output_mean_absolute_error: 6.9278 - gender_output_accuracy: 0.7214 - gender_output_loss: 0.5354 - loss: 5.0101 - val_age_output_loss: 9.3702 - val_age_output_mean_absolute_error: 9.3702 - val_gender_output_accuracy: 0.7610 - val_gender_output_loss: 0.4911 - val_loss: 6.7211
# Epoch 36/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.2332 - age_output_mean_absolute_error: 7.2332 - gender_output_accuracy: 0.7209 - gender_output_loss: 0.5456 - loss: 5.2269 - val_age_output_loss: 9.3186 - val_age_output_mean_absolute_error: 9.3186 - val_gender_output_accuracy: 0.7730 - val_gender_output_loss: 0.4840 - val_loss: 6.6179
# Epoch 37/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.2475 - age_output_mean_absolute_error: 7.2475 - gender_output_accuracy: 0.7430 - gender_output_loss: 0.5217 - loss: 5.2298 - val_age_output_loss: 8.8299 - val_age_output_mean_absolute_error: 8.8299 - val_gender_output_accuracy: 0.7330 - val_gender_output_loss: 0.5133 - val_loss: 6.3817
# Epoch 38/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.9943 - age_output_mean_absolute_error: 6.9943 - gender_output_accuracy: 0.7399 - gender_output_loss: 0.5188 - loss: 5.0516 - val_age_output_loss: 8.8919 - val_age_output_mean_absolute_error: 8.8919 - val_gender_output_accuracy: 0.7500 - val_gender_output_loss: 0.4875 - val_loss: 6.3832
# Epoch 39/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.0707 - age_output_mean_absolute_error: 7.0707 - gender_output_accuracy: 0.7264 - gender_output_loss: 0.5394 - loss: 5.1113 - val_age_output_loss: 8.9066 - val_age_output_mean_absolute_error: 8.9066 - val_gender_output_accuracy: 0.7430 - val_gender_output_loss: 0.4962 - val_loss: 6.3359
# Epoch 40/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.7809 - age_output_mean_absolute_error: 6.7809 - gender_output_accuracy: 0.7241 - gender_output_loss: 0.5349 - loss: 4.9071 - val_age_output_loss: 8.3679 - val_age_output_mean_absolute_error: 8.3679 - val_gender_output_accuracy: 0.7570 - val_gender_output_loss: 0.4831 - val_loss: 5.9638
# Epoch 41/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.0914 - age_output_mean_absolute_error: 7.0914 - gender_output_accuracy: 0.7429 - gender_output_loss: 0.5131 - loss: 5.1179 - val_age_output_loss: 8.7107 - val_age_output_mean_absolute_error: 8.7107 - val_gender_output_accuracy: 0.7910 - val_gender_output_loss: 0.4559 - val_loss: 6.2338
# Epoch 42/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - age_output_loss: 6.8756 - age_output_mean_absolute_error: 6.8756 - gender_output_accuracy: 0.7465 - gender_output_loss: 0.5117 - loss: 4.9664 - val_age_output_loss: 7.8146 - val_age_output_mean_absolute_error: 7.8146 - val_gender_output_accuracy: 0.7940 - val_gender_output_loss: 0.4390 - val_loss: 5.5935
# Epoch 43/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 7.0697 - age_output_mean_absolute_error: 7.0697 - gender_output_accuracy: 0.7592 - gender_output_loss: 0.5028 - loss: 5.0996 - val_age_output_loss: 8.8108 - val_age_output_mean_absolute_error: 8.8108 - val_gender_output_accuracy: 0.7920 - val_gender_output_loss: 0.4474 - val_loss: 6.2038
# Epoch 44/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.8312 - age_output_mean_absolute_error: 6.8312 - gender_output_accuracy: 0.7561 - gender_output_loss: 0.4949 - loss: 4.9303 - val_age_output_loss: 8.9884 - val_age_output_mean_absolute_error: 8.9884 - val_gender_output_accuracy: 0.7140 - val_gender_output_loss: 0.5074 - val_loss: 6.4737
# Epoch 45/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.5789 - age_output_mean_absolute_error: 6.5789 - gender_output_accuracy: 0.7591 - gender_output_loss: 0.4822 - loss: 4.7499 - val_age_output_loss: 8.5802 - val_age_output_mean_absolute_error: 8.5802 - val_gender_output_accuracy: 0.7880 - val_gender_output_loss: 0.4473 - val_loss: 6.1282
# Epoch 46/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.5689 - age_output_mean_absolute_error: 6.5689 - gender_output_accuracy: 0.7592 - gender_output_loss: 0.4822 - loss: 4.7429 - val_age_output_loss: 7.5397 - val_age_output_mean_absolute_error: 7.5397 - val_gender_output_accuracy: 0.7590 - val_gender_output_loss: 0.4656 - val_loss: 5.3855
# Epoch 47/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.7545 - age_output_mean_absolute_error: 6.7545 - gender_output_accuracy: 0.7529 - gender_output_loss: 0.5058 - loss: 4.8799 - val_age_output_loss: 8.2477 - val_age_output_mean_absolute_error: 8.2477 - val_gender_output_accuracy: 0.7930 - val_gender_output_loss: 0.4536 - val_loss: 5.8776
# Epoch 48/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.5614 - age_output_mean_absolute_error: 6.5614 - gender_output_accuracy: 0.7571 - gender_output_loss: 0.4856 - loss: 4.7387 - val_age_output_loss: 7.9257 - val_age_output_mean_absolute_error: 7.9257 - val_gender_output_accuracy: 0.7800 - val_gender_output_loss: 0.4357 - val_loss: 5.6034
# Epoch 49/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - age_output_loss: 6.5196 - age_output_mean_absolute_error: 6.5196 - gender_output_accuracy: 0.7531 - gender_output_loss: 0.4988 - loss: 4.7134 - val_age_output_loss: 7.5513 - val_age_output_mean_absolute_error: 7.5513 - val_gender_output_accuracy: 0.8010 - val_gender_output_loss: 0.4209 - val_loss: 5.3943
# Epoch 50/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - age_output_loss: 6.3661 - age_output_mean_absolute_error: 6.3661 - gender_output_accuracy: 0.7598 - gender_output_loss: 0.4799 - loss: 4.6002 - val_age_output_loss: 7.6819 - val_age_output_mean_absolute_error: 7.6819 - val_gender_output_accuracy: 0.8080 - val_gender_output_loss: 0.4189 - val_loss: 5.4725
# Epoch 51/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.4143 - age_output_mean_absolute_error: 6.4143 - gender_output_accuracy: 0.7655 - gender_output_loss: 0.4817 - loss: 4.6345 - val_age_output_loss: 7.6629 - val_age_output_mean_absolute_error: 7.6629 - val_gender_output_accuracy: 0.7570 - val_gender_output_loss: 0.4629 - val_loss: 5.4484
# Epoch 52/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.4011 - age_output_mean_absolute_error: 6.4011 - gender_output_accuracy: 0.7534 - gender_output_loss: 0.4895 - loss: 4.6276 - val_age_output_loss: 8.5288 - val_age_output_mean_absolute_error: 8.5288 - val_gender_output_accuracy: 0.8030 - val_gender_output_loss: 0.4199 - val_loss: 6.0854
# Epoch 53/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.5351 - age_output_mean_absolute_error: 6.5351 - gender_output_accuracy: 0.7616 - gender_output_loss: 0.4795 - loss: 4.7184 - val_age_output_loss: 8.0771 - val_age_output_mean_absolute_error: 8.0771 - val_gender_output_accuracy: 0.7880 - val_gender_output_loss: 0.4447 - val_loss: 5.7234
# Epoch 54/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.3174 - age_output_mean_absolute_error: 6.3174 - gender_output_accuracy: 0.7663 - gender_output_loss: 0.4679 - loss: 4.5625 - val_age_output_loss: 7.8830 - val_age_output_mean_absolute_error: 7.8830 - val_gender_output_accuracy: 0.8170 - val_gender_output_loss: 0.3997 - val_loss: 5.5855
# Epoch 55/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.1915 - age_output_mean_absolute_error: 6.1915 - gender_output_accuracy: 0.7797 - gender_output_loss: 0.4634 - loss: 4.4730 - val_age_output_loss: 7.9593 - val_age_output_mean_absolute_error: 7.9593 - val_gender_output_accuracy: 0.8110 - val_gender_output_loss: 0.4017 - val_loss: 5.7030
# Epoch 56/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.1484 - age_output_mean_absolute_error: 6.1484 - gender_output_accuracy: 0.7752 - gender_output_loss: 0.4549 - loss: 4.4404 - val_age_output_loss: 7.7886 - val_age_output_mean_absolute_error: 7.7886 - val_gender_output_accuracy: 0.7910 - val_gender_output_loss: 0.4246 - val_loss: 5.5351
# Epoch 57/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.1848 - age_output_mean_absolute_error: 6.1848 - gender_output_accuracy: 0.7926 - gender_output_loss: 0.4353 - loss: 4.4600 - val_age_output_loss: 8.1602 - val_age_output_mean_absolute_error: 8.1602 - val_gender_output_accuracy: 0.8100 - val_gender_output_loss: 0.4055 - val_loss: 5.7717
# Epoch 58/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.2590 - age_output_mean_absolute_error: 6.2590 - gender_output_accuracy: 0.7891 - gender_output_loss: 0.4494 - loss: 4.5161 - val_age_output_loss: 7.8546 - val_age_output_mean_absolute_error: 7.8546 - val_gender_output_accuracy: 0.7930 - val_gender_output_loss: 0.4186 - val_loss: 5.6169
# Epoch 59/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 6.2200 - age_output_mean_absolute_error: 6.2200 - gender_output_accuracy: 0.7764 - gender_output_loss: 0.4594 - loss: 4.4918 - val_age_output_loss: 7.7124 - val_age_output_mean_absolute_error: 7.7124 - val_gender_output_accuracy: 0.8260 - val_gender_output_loss: 0.3869 - val_loss: 5.5094
# Epoch 60/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - age_output_loss: 5.9113 - age_output_mean_absolute_error: 5.9113 - gender_output_accuracy: 0.7816 - gender_output_loss: 0.4634 - loss: 4.2769 - val_age_output_loss: 7.6723 - val_age_output_mean_absolute_error: 7.6723 - val_gender_output_accuracy: 0.7980 - val_gender_output_loss: 0.4117 - val_loss: 5.4645

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four learning curve figures for model A as follows.
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
#
# Add your code here
#
dict1 = model_hist.history

print("Model A — Learning Curves")


# 1. Gender Classification — Loss
plt.figure(figsize=(5,5))
plt.plot(dict1['gender_output_loss'], label='Train Loss', color='blue')
plt.plot(dict1['val_gender_output_loss'], label='Validation Loss', color='orange')
plt.title('Gender Classification — Loss')
plt.xlabel('Epochs')
plt.ylabel('Binary Crossentropy')
plt.legend()
plt.grid(True)
plt.show()

print("")

# 2. Gender Classification — Accuracy
plt.figure(figsize=(5,5))
plt.plot(dict1['gender_output_accuracy'], label='Train Accuracy', color='blue')
plt.plot(dict1['val_gender_output_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Gender Classification — Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

print("")

# 3. Age Estimation — Loss

plt.figure(figsize=(5,5))
plt.plot(dict1['age_output_loss'], label='Train Loss', color='purple')
plt.plot(dict1['val_age_output_loss'], label='Validation Loss', color='brown')
plt.title('Age Estimation — Loss')
plt.xlabel('Epochs')
plt.ylabel('MAE Loss')
plt.legend()
plt.grid(True)
plt.show()

print("")

# 4. Age Estimation — MAE
plt.figure(figsize=(5,5))
plt.plot(dict1['age_output_mean_absolute_error'],
         label='Train MAE', color='teal')
plt.plot(dict1['val_age_output_mean_absolute_error'],
         label='Validation MAE', color='magenta')
plt.title('Age Estimation — MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model A — Learning Curves

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose an existing CNN architecture pre-trained on ImageNet and fine-tune it on this dataset.
#
# As with Model A, **do not resize the input image size**.
# Ensure that the output layer for **the gender branch has only 1 unit**.
#
# At the end of the cell, use `modelB.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsoluteError, BinaryCrossentropy
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping

# Load the pre-trained model
input_shape = (128, 128, 3)
inputs = layers.Input(shape=input_shape)

#early stopping
Early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, mode='min')

# Using VGG16 with ImageNet weights, without the top layer
base_model = VGG16(weights='imagenet', include_top=False, input_tensor=inputs)

# Freeze the base model (VGG16)
base_model.trainable = False

# Create a new model on top of the VGG16 base
x = base_model.output

# Shared dense layer
x = layers.Flatten()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.3)(x)

# Age prediction head
age_branch = layers.Dense(128, activation="relu")(x)
age_branch = layers.Dropout(0.3)(age_branch)
age_output = layers.Dense(1, name="age_output")(age_branch)

# Gender classification head
gender_branch = layers.Dense(128, activation="relu")(x)
gender_branch = layers.Dropout(0.3)(gender_branch)
gender_output = layers.Dense(1, activation="sigmoid", name="gender_output")(gender_branch)

# Build the complete model
modelB = Model(inputs=inputs, outputs=[age_output, gender_output], name="VGG16_age_gender")
modelB.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss={"age_output": MeanAbsoluteError(), "gender_output": BinaryCrossentropy()},
    loss_weights={"age_output": 0.6, "gender_output": 0.4},
    metrics={"age_output": MeanAbsoluteError(), "gender_output": "accuracy"}
)

# Display the model summary and plot the architecture
modelB.summary()
plot_model(modelB, to_file="modelB_architecture.png",show_shapes=True, dpi=100)
# Out:
# Model: "VGG16_age_gender"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 128, 128,  │      1,792 │ input_layer_6[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 128, 128,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 64, 64,    │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 64, 64,    │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 64, 64,    │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 32, 32,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 32, 32,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 32, 32,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 32, 32,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 16, 16,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 16, 16,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 16, 16,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 16, 16,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 8, 8, 512) │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 8, 8, 512) │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 8, 8, 512) │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 8, 8, 512) │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 4, 4, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_5 (Flatten) │ (None, 8192)      │          0 │ block5_pool[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 256)       │  2,097,408 │ flatten_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 256)       │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 128)       │     32,896 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 128)       │     32,896 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 128)       │          0 │ dense_19[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 128)       │          0 │ dense_20[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │        129 │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 1)         │        129 │ dropout_24[0][0]  │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 16,878,146 (64.39 MB)
#  Trainable params: 2,163,458 (8.25 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.keras` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
#
# Add your code here
#
history_modelB = modelB.fit(
    aug_train_dataset,
    epochs = 60,
    validation_data = aug_val_dataset,
    callbacks = [Early_stopping],
    verbose=1
)
modelB.save(folder_models+"age_gender_B.keras")
# Out:
# Epoch 1/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - age_output_loss: 21.1288 - age_output_mean_absolute_error: 21.1288 - gender_output_accuracy: 0.5149 - gender_output_loss: 1.0464 - loss: 13.0958 - val_age_output_loss: 13.0565 - val_age_output_mean_absolute_error: 13.0565 - val_gender_output_accuracy: 0.7130 - val_gender_output_loss: 0.5820 - val_loss: 8.0007
# Epoch 2/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 13.4816 - age_output_mean_absolute_error: 13.4816 - gender_output_accuracy: 0.5794 - gender_output_loss: 0.8448 - loss: 8.4269 - val_age_output_loss: 11.3425 - val_age_output_mean_absolute_error: 11.3425 - val_gender_output_accuracy: 0.7620 - val_gender_output_loss: 0.5308 - val_loss: 6.9589
# Epoch 3/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - age_output_loss: 11.7193 - age_output_mean_absolute_error: 11.7193 - gender_output_accuracy: 0.6422 - gender_output_loss: 0.6808 - loss: 7.3039 - val_age_output_loss: 10.5529 - val_age_output_mean_absolute_error: 10.5529 - val_gender_output_accuracy: 0.7750 - val_gender_output_loss: 0.5034 - val_loss: 6.4834
# Epoch 4/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - age_output_loss: 11.3109 - age_output_mean_absolute_error: 11.3109 - gender_output_accuracy: 0.6709 - gender_output_loss: 0.6313 - loss: 7.0390 - val_age_output_loss: 10.0021 - val_age_output_mean_absolute_error: 10.0021 - val_gender_output_accuracy: 0.7880 - val_gender_output_loss: 0.4682 - val_loss: 6.1398
# Epoch 5/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 10.8179 - age_output_mean_absolute_error: 10.8179 - gender_output_accuracy: 0.6934 - gender_output_loss: 0.5930 - loss: 6.7279 - val_age_output_loss: 9.5882 - val_age_output_mean_absolute_error: 9.5882 - val_gender_output_accuracy: 0.7960 - val_gender_output_loss: 0.4729 - val_loss: 5.9001
# Epoch 6/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 10.1885 - age_output_mean_absolute_error: 10.1885 - gender_output_accuracy: 0.7130 - gender_output_loss: 0.5550 - loss: 6.3351 - val_age_output_loss: 9.3475 - val_age_output_mean_absolute_error: 9.3475 - val_gender_output_accuracy: 0.8130 - val_gender_output_loss: 0.4431 - val_loss: 5.7425
# Epoch 7/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 10.1372 - age_output_mean_absolute_error: 10.1372 - gender_output_accuracy: 0.7245 - gender_output_loss: 0.5585 - loss: 6.3057 - val_age_output_loss: 8.9790 - val_age_output_mean_absolute_error: 8.9790 - val_gender_output_accuracy: 0.8050 - val_gender_output_loss: 0.4306 - val_loss: 5.5214
# Epoch 8/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 9.9394 - age_output_mean_absolute_error: 9.9394 - gender_output_accuracy: 0.7561 - gender_output_loss: 0.4992 - loss: 6.1633 - val_age_output_loss: 8.8835 - val_age_output_mean_absolute_error: 8.8835 - val_gender_output_accuracy: 0.8150 - val_gender_output_loss: 0.4175 - val_loss: 5.4548
# Epoch 9/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 9.4732 - age_output_mean_absolute_error: 9.4732 - gender_output_accuracy: 0.7602 - gender_output_loss: 0.4906 - loss: 5.8802 - val_age_output_loss: 8.7411 - val_age_output_mean_absolute_error: 8.7411 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.4056 - val_loss: 5.3623
# Epoch 10/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - age_output_loss: 9.4156 - age_output_mean_absolute_error: 9.4156 - gender_output_accuracy: 0.7669 - gender_output_loss: 0.4963 - loss: 5.8479 - val_age_output_loss: 9.0570 - val_age_output_mean_absolute_error: 9.0570 - val_gender_output_accuracy: 0.8100 - val_gender_output_loss: 0.4088 - val_loss: 5.5332
# Epoch 11/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 9.1207 - age_output_mean_absolute_error: 9.1207 - gender_output_accuracy: 0.7733 - gender_output_loss: 0.4870 - loss: 5.6672 - val_age_output_loss: 8.6419 - val_age_output_mean_absolute_error: 8.6419 - val_gender_output_accuracy: 0.8260 - val_gender_output_loss: 0.3869 - val_loss: 5.2710
# Epoch 12/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 8.8976 - age_output_mean_absolute_error: 8.8976 - gender_output_accuracy: 0.7964 - gender_output_loss: 0.4436 - loss: 5.5160 - val_age_output_loss: 8.4961 - val_age_output_mean_absolute_error: 8.4961 - val_gender_output_accuracy: 0.8340 - val_gender_output_loss: 0.3819 - val_loss: 5.1718
# Epoch 13/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 8.7888 - age_output_mean_absolute_error: 8.7888 - gender_output_accuracy: 0.7796 - gender_output_loss: 0.4470 - loss: 5.4521 - val_age_output_loss: 8.4235 - val_age_output_mean_absolute_error: 8.4235 - val_gender_output_accuracy: 0.8320 - val_gender_output_loss: 0.3717 - val_loss: 5.1342
# Epoch 14/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 8.6582 - age_output_mean_absolute_error: 8.6582 - gender_output_accuracy: 0.7895 - gender_output_loss: 0.4462 - loss: 5.3734 - val_age_output_loss: 8.5464 - val_age_output_mean_absolute_error: 8.5464 - val_gender_output_accuracy: 0.8230 - val_gender_output_loss: 0.3943 - val_loss: 5.2077
# Epoch 15/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 8.4834 - age_output_mean_absolute_error: 8.4834 - gender_output_accuracy: 0.7917 - gender_output_loss: 0.4365 - loss: 5.2647 - val_age_output_loss: 8.7514 - val_age_output_mean_absolute_error: 8.7514 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.3700 - val_loss: 5.3203
# Epoch 16/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 8.1477 - age_output_mean_absolute_error: 8.1477 - gender_output_accuracy: 0.8090 - gender_output_loss: 0.4243 - loss: 5.0583 - val_age_output_loss: 8.3757 - val_age_output_mean_absolute_error: 8.3757 - val_gender_output_accuracy: 0.8340 - val_gender_output_loss: 0.3609 - val_loss: 5.0936
# Epoch 17/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 8.1755 - age_output_mean_absolute_error: 8.1755 - gender_output_accuracy: 0.8066 - gender_output_loss: 0.4194 - loss: 5.0730 - val_age_output_loss: 8.3369 - val_age_output_mean_absolute_error: 8.3369 - val_gender_output_accuracy: 0.8330 - val_gender_output_loss: 0.3642 - val_loss: 5.0717
# Epoch 18/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 8.2459 - age_output_mean_absolute_error: 8.2459 - gender_output_accuracy: 0.8108 - gender_output_loss: 0.4282 - loss: 5.1189 - val_age_output_loss: 8.5898 - val_age_output_mean_absolute_error: 8.5898 - val_gender_output_accuracy: 0.8360 - val_gender_output_loss: 0.3523 - val_loss: 5.2143
# Epoch 19/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.9715 - age_output_mean_absolute_error: 7.9715 - gender_output_accuracy: 0.8257 - gender_output_loss: 0.3921 - loss: 4.9397 - val_age_output_loss: 9.0105 - val_age_output_mean_absolute_error: 9.0105 - val_gender_output_accuracy: 0.8350 - val_gender_output_loss: 0.3475 - val_loss: 5.4599
# Epoch 20/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.9339 - age_output_mean_absolute_error: 7.9339 - gender_output_accuracy: 0.8156 - gender_output_loss: 0.3945 - loss: 4.9181 - val_age_output_loss: 8.2632 - val_age_output_mean_absolute_error: 8.2632 - val_gender_output_accuracy: 0.8450 - val_gender_output_loss: 0.3496 - val_loss: 5.0298
# Epoch 21/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 8.0714 - age_output_mean_absolute_error: 8.0714 - gender_output_accuracy: 0.8282 - gender_output_loss: 0.3861 - loss: 4.9973 - val_age_output_loss: 8.2309 - val_age_output_mean_absolute_error: 8.2309 - val_gender_output_accuracy: 0.8450 - val_gender_output_loss: 0.3494 - val_loss: 5.0088
# Epoch 22/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.6724 - age_output_mean_absolute_error: 7.6724 - gender_output_accuracy: 0.8179 - gender_output_loss: 0.3924 - loss: 4.7604 - val_age_output_loss: 8.2436 - val_age_output_mean_absolute_error: 8.2436 - val_gender_output_accuracy: 0.8470 - val_gender_output_loss: 0.3405 - val_loss: 5.0000
# Epoch 23/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.5940 - age_output_mean_absolute_error: 7.5940 - gender_output_accuracy: 0.8213 - gender_output_loss: 0.3915 - loss: 4.7130 - val_age_output_loss: 8.4517 - val_age_output_mean_absolute_error: 8.4517 - val_gender_output_accuracy: 0.8420 - val_gender_output_loss: 0.3357 - val_loss: 5.1173
# Epoch 24/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.6682 - age_output_mean_absolute_error: 7.6682 - gender_output_accuracy: 0.8359 - gender_output_loss: 0.3679 - loss: 4.7481 - val_age_output_loss: 8.2125 - val_age_output_mean_absolute_error: 8.2125 - val_gender_output_accuracy: 0.8420 - val_gender_output_loss: 0.3433 - val_loss: 4.9951
# Epoch 25/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 7.5358 - age_output_mean_absolute_error: 7.5358 - gender_output_accuracy: 0.8313 - gender_output_loss: 0.3882 - loss: 4.6768 - val_age_output_loss: 8.0414 - val_age_output_mean_absolute_error: 8.0414 - val_gender_output_accuracy: 0.8430 - val_gender_output_loss: 0.3328 - val_loss: 4.8815
# Epoch 26/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 7.2105 - age_output_mean_absolute_error: 7.2105 - gender_output_accuracy: 0.8250 - gender_output_loss: 0.3853 - loss: 4.4804 - val_age_output_loss: 8.3249 - val_age_output_mean_absolute_error: 8.3249 - val_gender_output_accuracy: 0.8500 - val_gender_output_loss: 0.3381 - val_loss: 5.0489
# Epoch 27/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.6653 - age_output_mean_absolute_error: 7.6653 - gender_output_accuracy: 0.8346 - gender_output_loss: 0.3665 - loss: 4.7458 - val_age_output_loss: 8.2808 - val_age_output_mean_absolute_error: 8.2808 - val_gender_output_accuracy: 0.8430 - val_gender_output_loss: 0.3462 - val_loss: 5.0094
# Epoch 28/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.3744 - age_output_mean_absolute_error: 7.3744 - gender_output_accuracy: 0.8336 - gender_output_loss: 0.3718 - loss: 4.5734 - val_age_output_loss: 8.3988 - val_age_output_mean_absolute_error: 8.3988 - val_gender_output_accuracy: 0.8480 - val_gender_output_loss: 0.3296 - val_loss: 5.0727
# Epoch 29/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 7.2657 - age_output_mean_absolute_error: 7.2657 - gender_output_accuracy: 0.8364 - gender_output_loss: 0.3581 - loss: 4.5027 - val_age_output_loss: 8.0826 - val_age_output_mean_absolute_error: 8.0826 - val_gender_output_accuracy: 0.8530 - val_gender_output_loss: 0.3280 - val_loss: 4.8886
# Epoch 30/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.3353 - age_output_mean_absolute_error: 7.3353 - gender_output_accuracy: 0.8420 - gender_output_loss: 0.3637 - loss: 4.5467 - val_age_output_loss: 8.1702 - val_age_output_mean_absolute_error: 8.1702 - val_gender_output_accuracy: 0.8550 - val_gender_output_loss: 0.3247 - val_loss: 4.9505
# Epoch 31/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.1484 - age_output_mean_absolute_error: 7.1484 - gender_output_accuracy: 0.8412 - gender_output_loss: 0.3495 - loss: 4.4288 - val_age_output_loss: 8.0359 - val_age_output_mean_absolute_error: 8.0359 - val_gender_output_accuracy: 0.8450 - val_gender_output_loss: 0.3344 - val_loss: 4.8642
# Epoch 32/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.3989 - age_output_mean_absolute_error: 7.3989 - gender_output_accuracy: 0.8452 - gender_output_loss: 0.3497 - loss: 4.5792 - val_age_output_loss: 8.0712 - val_age_output_mean_absolute_error: 8.0712 - val_gender_output_accuracy: 0.8530 - val_gender_output_loss: 0.3269 - val_loss: 4.8878
# Epoch 33/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.1046 - age_output_mean_absolute_error: 7.1046 - gender_output_accuracy: 0.8402 - gender_output_loss: 0.3478 - loss: 4.4019 - val_age_output_loss: 8.0506 - val_age_output_mean_absolute_error: 8.0506 - val_gender_output_accuracy: 0.8600 - val_gender_output_loss: 0.3177 - val_loss: 4.8709
# Epoch 34/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.2187 - age_output_mean_absolute_error: 7.2187 - gender_output_accuracy: 0.8558 - gender_output_loss: 0.3329 - loss: 4.4644 - val_age_output_loss: 8.0230 - val_age_output_mean_absolute_error: 8.0230 - val_gender_output_accuracy: 0.8520 - val_gender_output_loss: 0.3213 - val_loss: 4.8528
# Epoch 35/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.0298 - age_output_mean_absolute_error: 7.0298 - gender_output_accuracy: 0.8471 - gender_output_loss: 0.3550 - loss: 4.3599 - val_age_output_loss: 8.3174 - val_age_output_mean_absolute_error: 8.3174 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3216 - val_loss: 5.0291
# Epoch 36/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.9718 - age_output_mean_absolute_error: 6.9718 - gender_output_accuracy: 0.8597 - gender_output_loss: 0.3297 - loss: 4.3150 - val_age_output_loss: 8.0013 - val_age_output_mean_absolute_error: 8.0013 - val_gender_output_accuracy: 0.8580 - val_gender_output_loss: 0.3343 - val_loss: 4.8463
# Epoch 37/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.9515 - age_output_mean_absolute_error: 6.9515 - gender_output_accuracy: 0.8581 - gender_output_loss: 0.3213 - loss: 4.2994 - val_age_output_loss: 8.0799 - val_age_output_mean_absolute_error: 8.0799 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3122 - val_loss: 4.8775
# Epoch 38/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 7.0888 - age_output_mean_absolute_error: 7.0888 - gender_output_accuracy: 0.8497 - gender_output_loss: 0.3420 - loss: 4.3901 - val_age_output_loss: 7.9686 - val_age_output_mean_absolute_error: 7.9686 - val_gender_output_accuracy: 0.8590 - val_gender_output_loss: 0.3241 - val_loss: 4.8290
# Epoch 39/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.9441 - age_output_mean_absolute_error: 6.9441 - gender_output_accuracy: 0.8530 - gender_output_loss: 0.3374 - loss: 4.3014 - val_age_output_loss: 8.1645 - val_age_output_mean_absolute_error: 8.1645 - val_gender_output_accuracy: 0.8470 - val_gender_output_loss: 0.3297 - val_loss: 4.9336
# Epoch 40/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 6.8726 - age_output_mean_absolute_error: 6.8726 - gender_output_accuracy: 0.8536 - gender_output_loss: 0.3369 - loss: 4.2583 - val_age_output_loss: 8.1371 - val_age_output_mean_absolute_error: 8.1371 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.3148 - val_loss: 4.9327
# Epoch 41/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.8316 - age_output_mean_absolute_error: 6.8316 - gender_output_accuracy: 0.8520 - gender_output_loss: 0.3341 - loss: 4.2326 - val_age_output_loss: 8.0962 - val_age_output_mean_absolute_error: 8.0962 - val_gender_output_accuracy: 0.8480 - val_gender_output_loss: 0.3263 - val_loss: 4.8974
# Epoch 42/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.9194 - age_output_mean_absolute_error: 6.9194 - gender_output_accuracy: 0.8695 - gender_output_loss: 0.3184 - loss: 4.2790 - val_age_output_loss: 7.9448 - val_age_output_mean_absolute_error: 7.9448 - val_gender_output_accuracy: 0.8590 - val_gender_output_loss: 0.3138 - val_loss: 4.8082
# Epoch 43/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.8229 - age_output_mean_absolute_error: 6.8229 - gender_output_accuracy: 0.8578 - gender_output_loss: 0.3363 - loss: 4.2283 - val_age_output_loss: 7.9275 - val_age_output_mean_absolute_error: 7.9275 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3099 - val_loss: 4.7963
# Epoch 44/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.8641 - age_output_mean_absolute_error: 6.8641 - gender_output_accuracy: 0.8534 - gender_output_loss: 0.3302 - loss: 4.2506 - val_age_output_loss: 7.9382 - val_age_output_mean_absolute_error: 7.9382 - val_gender_output_accuracy: 0.8580 - val_gender_output_loss: 0.3158 - val_loss: 4.8012
# Epoch 45/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 6.5817 - age_output_mean_absolute_error: 6.5817 - gender_output_accuracy: 0.8573 - gender_output_loss: 0.3153 - loss: 4.0751 - val_age_output_loss: 7.9640 - val_age_output_mean_absolute_error: 7.9640 - val_gender_output_accuracy: 0.8640 - val_gender_output_loss: 0.3091 - val_loss: 4.8271
# Epoch 46/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.8584 - age_output_mean_absolute_error: 6.8584 - gender_output_accuracy: 0.8548 - gender_output_loss: 0.3217 - loss: 4.2437 - val_age_output_loss: 8.1803 - val_age_output_mean_absolute_error: 8.1803 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3113 - val_loss: 4.9349
# Epoch 47/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.7313 - age_output_mean_absolute_error: 6.7313 - gender_output_accuracy: 0.8612 - gender_output_loss: 0.3256 - loss: 4.1690 - val_age_output_loss: 8.0018 - val_age_output_mean_absolute_error: 8.0018 - val_gender_output_accuracy: 0.8580 - val_gender_output_loss: 0.3135 - val_loss: 4.8347
# Epoch 48/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.4987 - age_output_mean_absolute_error: 6.4987 - gender_output_accuracy: 0.8606 - gender_output_loss: 0.3232 - loss: 4.0285 - val_age_output_loss: 8.0187 - val_age_output_mean_absolute_error: 8.0187 - val_gender_output_accuracy: 0.8630 - val_gender_output_loss: 0.3129 - val_loss: 4.8400
# Epoch 49/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.5465 - age_output_mean_absolute_error: 6.5465 - gender_output_accuracy: 0.8612 - gender_output_loss: 0.3110 - loss: 4.0523 - val_age_output_loss: 8.1418 - val_age_output_mean_absolute_error: 8.1418 - val_gender_output_accuracy: 0.8590 - val_gender_output_loss: 0.3074 - val_loss: 4.9082
# Epoch 50/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.3817 - age_output_mean_absolute_error: 6.3817 - gender_output_accuracy: 0.8577 - gender_output_loss: 0.3191 - loss: 3.9567 - val_age_output_loss: 8.0388 - val_age_output_mean_absolute_error: 8.0388 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3157 - val_loss: 4.8533
# Epoch 51/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 6.4535 - age_output_mean_absolute_error: 6.4535 - gender_output_accuracy: 0.8582 - gender_output_loss: 0.3068 - loss: 3.9948 - val_age_output_loss: 7.9094 - val_age_output_mean_absolute_error: 7.9094 - val_gender_output_accuracy: 0.8550 - val_gender_output_loss: 0.3234 - val_loss: 4.7842
# Epoch 52/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.5688 - age_output_mean_absolute_error: 6.5688 - gender_output_accuracy: 0.8576 - gender_output_loss: 0.3127 - loss: 4.0663 - val_age_output_loss: 8.0922 - val_age_output_mean_absolute_error: 8.0922 - val_gender_output_accuracy: 0.8620 - val_gender_output_loss: 0.3123 - val_loss: 4.8857
# Epoch 53/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.4178 - age_output_mean_absolute_error: 6.4178 - gender_output_accuracy: 0.8680 - gender_output_loss: 0.2877 - loss: 3.9658 - val_age_output_loss: 8.0713 - val_age_output_mean_absolute_error: 8.0713 - val_gender_output_accuracy: 0.8620 - val_gender_output_loss: 0.3180 - val_loss: 4.8726
# Epoch 54/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.5326 - age_output_mean_absolute_error: 6.5326 - gender_output_accuracy: 0.8565 - gender_output_loss: 0.3161 - loss: 4.0460 - val_age_output_loss: 8.0553 - val_age_output_mean_absolute_error: 8.0553 - val_gender_output_accuracy: 0.8620 - val_gender_output_loss: 0.3195 - val_loss: 4.8666
# Epoch 55/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 6.2435 - age_output_mean_absolute_error: 6.2435 - gender_output_accuracy: 0.8577 - gender_output_loss: 0.3143 - loss: 3.8718 - val_age_output_loss: 7.9343 - val_age_output_mean_absolute_error: 7.9343 - val_gender_output_accuracy: 0.8550 - val_gender_output_loss: 0.3409 - val_loss: 4.8188
# Epoch 56/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 6.3717 - age_output_mean_absolute_error: 6.3717 - gender_output_accuracy: 0.8704 - gender_output_loss: 0.2890 - loss: 3.9386 - val_age_output_loss: 8.1623 - val_age_output_mean_absolute_error: 8.1623 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.3272 - val_loss: 4.9340
# Epoch 57/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.3165 - age_output_mean_absolute_error: 6.3165 - gender_output_accuracy: 0.8750 - gender_output_loss: 0.2868 - loss: 3.9046 - val_age_output_loss: 8.0129 - val_age_output_mean_absolute_error: 8.0129 - val_gender_output_accuracy: 0.8580 - val_gender_output_loss: 0.3152 - val_loss: 4.8620
# Epoch 58/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - age_output_loss: 6.2921 - age_output_mean_absolute_error: 6.2921 - gender_output_accuracy: 0.8819 - gender_output_loss: 0.2773 - loss: 3.8862 - val_age_output_loss: 8.2006 - val_age_output_mean_absolute_error: 8.2006 - val_gender_output_accuracy: 0.8600 - val_gender_output_loss: 0.3130 - val_loss: 4.9529
# Epoch 59/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.1484 - age_output_mean_absolute_error: 6.1484 - gender_output_accuracy: 0.8663 - gender_output_loss: 0.2822 - loss: 3.8019 - val_age_output_loss: 8.1450 - val_age_output_mean_absolute_error: 8.1450 - val_gender_output_accuracy: 0.8550 - val_gender_output_loss: 0.3241 - val_loss: 4.9168
# Epoch 60/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - age_output_loss: 6.0816 - age_output_mean_absolute_error: 6.0816 - gender_output_accuracy: 0.8750 - gender_output_loss: 0.2893 - loss: 3.7647 - val_age_output_loss: 8.1064 - val_age_output_mean_absolute_error: 8.1064 - val_gender_output_accuracy: 0.8630 - val_gender_output_loss: 0.3178 - val_loss: 4.8953

# %% [markdown]
# ## STEP4B: Draw the learning curves
# Draw four learning curve figures for model B as follows.
# 1. The loss of the gender classification over the training and validation set
# 2. The accuracy of the gender classification over the training and validation set
# 3. The loss of the age estimation over the training and validation set
# 4. The MAE of the age estimation over the training and validation set

# %%
#
# Add your code here
#
dict2 = history_modelB.history

print("Model B — Learning Curves")


# 1. Gender Classification — Loss
plt.figure(figsize=(5,5))
plt.plot(dict2['gender_output_loss'], label='Train Loss', color='blue')
plt.plot(dict2['val_gender_output_loss'], label='Validation Loss', color='orange')
plt.title('Gender Classification — Loss')
plt.xlabel('Epochs')
plt.ylabel('Binary Crossentropy')
plt.legend()
plt.grid(True)
plt.show()

print("")

# 2. Gender Classification — Accuracy
plt.figure(figsize=(5,5))
plt.plot(dict2['gender_output_accuracy'], label='Train Accuracy', color='blue')
plt.plot(dict2['val_gender_output_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Gender Classification — Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

print("")

# 3. Age Estimation — Loss

plt.figure(figsize=(5,5))
plt.plot(dict2['age_output_loss'], label='Train Loss', color='purple')
plt.plot(dict2['val_age_output_loss'], label='Validation Loss', color='brown')
plt.title('Age Estimation — Loss')
plt.xlabel('Epochs')
plt.ylabel('MAE Loss')
plt.legend()
plt.grid(True)
plt.show()

print("")

# 4. Age Estimation — MAE
plt.figure(figsize=(5,5))
plt.plot(dict2['age_output_mean_absolute_error'],label='Train MAE', color='teal')
plt.plot(dict2['val_age_output_mean_absolute_error'],label='Validation MAE', color='magenta')
plt.title('Age Estimation — MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model B — Learning Curves

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will load your two models for testing. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
